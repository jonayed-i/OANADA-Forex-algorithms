# %% [markdown]
# # Financial Data Analysis

# %% [markdown]
# ## Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "NVDA", "INTC", "IBM", "QYLD", "MSFT" ]

# %%
stocks = yf.download(ticker, start = "2017-01-01", end = "2021-06-06")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#             Adj Close                                                \
#                  AAPL         IBM       INTC       MSFT        NVDA
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300
#
#                            Close                                    ...  \
#                  QYLD       AAPL         IBM       INTC       MSFT  ...
# Date                                                                ...
# 2017-01-03  14.211367  29.037500  167.190002  36.599998  62.580002  ...
# 2017-01-04  14.300344  29.004999  169.259995  36.410000  62.299999  ...
# 2017-01-05  14.338478  29.152500  168.699997  36.349998  62.299999  ...
# 2017-01-06  14.402037  29.477501  169.529999  36.480000  62.840000  ...
# 2017-01-09  14.452879  29.747499  167.649994  36.610001  62.639999  ...
#
#                  Open                                       Volume           \
#                  INTC       MSFT        NVDA       QYLD       AAPL      IBM
# Date
# 2017-01-03  36.610001  62.790001  104.400002  22.500000  115127600  2934300
# 2017-01-04  36.709999  62.480000  103.400002  22.500000   84472400  3381400
# 2017-01-05  36.450001  62.189999  104.529999  22.450001   88774400  2682300
# 2017-01-06  36.590000  62.299999  102.849998  22.645000  127007600  2945500
# 2017-01-09  36.480000  62.759998  103.500000  22.650000  134247600  3189900
#
#
#                 INTC      MSFT      NVDA   QYLD
# Date
# 2017-01-03  20196500  20694100  37549900  22700
# 2017-01-04  15915700  21340000  29980500  13100
# 2017-01-05  13986000  24876000  24607400  28200
# 2017-01-06  15114000  19922900  20571400  31600
# 2017-01-09  19461400  20382700  22906200  22900
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL         IBM       INTC        MSFT        NVDA
# Date
# 2021-05-28  124.610001  143.740005  57.119999  249.679993  649.780029
# 2021-06-01  124.279999  144.190002  56.889999  247.399994  650.580017
# 2021-06-02  125.059998  145.720001  57.480000  247.300003  671.130005
# 2021-06-03  123.540001  145.550003  56.240002  245.710007  678.789978
# 2021-06-04  125.889999  147.419998  57.369999  250.789993  703.130005
#
#                             Close                                     ...  \
#                  QYLD        AAPL         IBM       INTC        MSFT  ...
# Date                                                                  ...
# 2021-05-28  22.209999  124.610001  143.740005  57.119999  249.679993  ...
# 2021-06-01  22.230000  124.279999  144.190002  56.889999  247.399994  ...
# 2021-06-02  22.250000  125.059998  145.720001  57.480000  247.300003  ...
# 2021-06-03  22.160000  123.540001  145.550003  56.240002  245.710007  ...
# 2021-06-04  22.330000  125.889999  147.419998  57.369999  250.789993  ...
#
#                  Open                                       Volume           \
#                  INTC        MSFT        NVDA       QYLD      AAPL      IBM
# Date
# 2021-05-28  57.549999  251.000000  620.039978  22.226999  71311100  2534600
# 2021-06-01  57.610001  251.229996  650.799988  22.260000  67637100  2417500
# 2021-06-02  56.910000  248.130005  650.090027  22.270000  59278900  2786900
# 2021-06-03  56.980000  245.220001  668.030029  22.190001  76229200  4130600
# 2021-06-04  56.549999  247.759995  684.500000  22.260000  75087300  3116700
#
#
#                 INTC      MSFT      NVDA     QYLD
# Date
# 2021-05-28  20303900  18270200  16113400  1363200
# 2021-06-01  20326400  23213300  11820100  2049000
# 2021-06-02  18483600  19406700  14854200  2631700
# 2021-06-03  21831300  25307700  14500200  2079000
# 2021-06-04  21487300  25275000  15411300  2118700
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1113 entries, 2017-01-03 to 2021-06-04
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1113 non-null   float64
#  1   (Adj Close, IBM)   1113 non-null   float64
#  2   (Adj Close, INTC)  1113 non-null   float64
#  3   (Adj Close, MSFT)  1113 non-null   float64
#  4   (Adj Close, NVDA)  1113 non-null   float64
#  5   (Adj Close, QYLD)  1113 non-null   float64
#  6   (Close, AAPL)      1113 non-null   float64
#  7   (Close, IBM)       1113 non-null   float64
#  8   (Close, INTC)      1113 non-null   float64
#  9   (Close, MSFT)      1113 non-null   float64
#  10  (Close, NVDA)      1113 non-null   float64
#  11  (Close, QYLD)      1113 non-null   float64
#  12  (High, AAPL)       1113 non-null   float64
#  13  (High, IBM)        1113 non-null   float64
#  14  (High, INTC)       1113 non-null   float64
#  15  (High, MSFT)       1113 non-null   float64
#  16  (High, NVDA)       1113 non-null   float64
#  17  (High, QYLD)       1113 non-null   float64
#  18  (Low, AAPL)        1113 non-null   float64
#  19  (Low, IBM)         1113 non-null   float64
#  20  (Low, INTC)        1113 non-null   float64
#  21  (Low, MSFT)        1113 non-null   float64
#  22  (Low, NVDA)        1113 non-null   float64
#  23  (Low, QYLD)        1113 non-null   float64
#  24  (Open, AAPL)       1113 non-null   float64
#  25  (Open, IBM)        1113 non-null   float64
#  26  (Open, INTC)       1113 non-null   float64
#  27  (Open, MSFT)       1113 non-null   float64
#  28  (Open, NVDA)       1113 non-null   float64
#  29  (Open, QYLD)       1113 non-null   float64
#  30  (Volume, AAPL)     1113 non-null   int64
#  31  (Volume, IBM)      1113 non-null   int64
#  32  (Volume, INTC)     1113 non-null   int64
#  33  (Volume, MSFT)     1113 non-null   int64
#  34  (Volume, NVDA)     1113 non-null   int64
#  35  (Volume, QYLD)     1113 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 321.7 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
#             Adj Close                                                \
#                  AAPL         IBM       INTC       MSFT        NVDA
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300
#
#                            Close                                    ...  \
#                  QYLD       AAPL         IBM       INTC       MSFT  ...
# Date                                                                ...
# 2017-01-03  14.211367  29.037500  167.190002  36.599998  62.580002  ...
# 2017-01-04  14.300344  29.004999  169.259995  36.410000  62.299999  ...
# 2017-01-05  14.338478  29.152500  168.699997  36.349998  62.299999  ...
# 2017-01-06  14.402037  29.477501  169.529999  36.480000  62.840000  ...
# 2017-01-09  14.452879  29.747499  167.649994  36.610001  62.639999  ...
#
#                  Open                                       Volume           \
#                  INTC       MSFT        NVDA       QYLD       AAPL      IBM
# Date
# 2017-01-03  36.610001  62.790001  104.400002  22.500000  115127600  2934300
# 2017-01-04  36.709999  62.480000  103.400002  22.500000   84472400  3381400
# 2017-01-05  36.450001  62.189999  104.529999  22.450001   88774400  2682300
# 2017-01-06  36.590000  62.299999  102.849998  22.645000  127007600  2945500
# 2017-01-09  36.480000  62.759998  103.500000  22.650000  134247600  3189900
#
#
#                 INTC      MSFT      NVDA   QYLD
# Date
# 2017-01-03  20196500  20694100  37549900  22700
# 2017-01-04  15915700  21340000  29980500  13100
# 2017-01-05  13986000  24876000  24607400  28200
# 2017-01-06  15114000  19922900  20571400  31600
# 2017-01-09  19461400  20382700  22906200  22900
#
# [5 rows x 36 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'IBM'), ('Adj Close', 'INTC'),
#        ('Adj Close', 'MSFT'), ('Adj Close', 'NVDA'), ('Adj Close', 'QYLD'),
#            ('Close', 'AAPL'),      ('Close', 'IBM'),     ('Close', 'INTC'),
#            ('Close', 'MSFT'),     ('Close', 'NVDA'),     ('Close', 'QYLD'),
#             ('High', 'AAPL'),       ('High', 'IBM'),      ('High', 'INTC'),
#             ('High', 'MSFT'),      ('High', 'NVDA'),      ('High', 'QYLD'),
#              ('Low', 'AAPL'),        ('Low', 'IBM'),       ('Low', 'INTC'),
#              ('Low', 'MSFT'),       ('Low', 'NVDA'),       ('Low', 'QYLD'),
#             ('Open', 'AAPL'),       ('Open', 'IBM'),      ('Open', 'INTC'),
#             ('Open', 'MSFT'),      ('Open', 'NVDA'),      ('Open', 'QYLD'),
#           ('Volume', 'AAPL'),     ('Volume', 'IBM'),    ('Volume', 'INTC'),
#           ('Volume', 'MSFT'),    ('Volume', 'NVDA'),    ('Volume', 'QYLD')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#             Adj Close                                                \
#                  AAPL         IBM       INTC       MSFT        NVDA
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300
#
#                            Close                                    ...  \
#                  QYLD       AAPL         IBM       INTC       MSFT  ...
# Date                                                                ...
# 2017-01-03  14.211367  29.037500  167.190002  36.599998  62.580002  ...
# 2017-01-04  14.300344  29.004999  169.259995  36.410000  62.299999  ...
# 2017-01-05  14.338478  29.152500  168.699997  36.349998  62.299999  ...
# 2017-01-06  14.402037  29.477501  169.529999  36.480000  62.840000  ...
# 2017-01-09  14.452879  29.747499  167.649994  36.610001  62.639999  ...
#
#                  Open                                       Volume           \
#                  INTC       MSFT        NVDA       QYLD       AAPL      IBM
# Date
# 2017-01-03  36.610001  62.790001  104.400002  22.500000  115127600  2934300
# 2017-01-04  36.709999  62.480000  103.400002  22.500000   84472400  3381400
# 2017-01-05  36.450001  62.189999  104.529999  22.450001   88774400  2682300
# 2017-01-06  36.590000  62.299999  102.849998  22.645000  127007600  2945500
# 2017-01-09  36.480000  62.759998  103.500000  22.650000  134247600  3189900
#
#
#                 INTC      MSFT      NVDA   QYLD
# Date
# 2017-01-03  20196500  20694100  37549900  22700
# 2017-01-04  15915700  21340000  29980500  13100
# 2017-01-05  13986000  24876000  24607400  28200
# 2017-01-06  15114000  19922900  20571400  31600
# 2017-01-09  19461400  20382700  22906200  22900
#
# [5 rows x 36 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1)
# Out:
#                   AAPL                                                  \
#              Adj Close       Close        High         Low        Open
# Date
# 2017-01-03   27.413372   29.037500   29.082500   28.690001   28.950001
# 2017-01-04   27.382690   29.004999   29.127501   28.937500   28.962500
# 2017-01-05   27.521944   29.152500   29.215000   28.952499   28.980000
# 2017-01-06   27.828764   29.477501   29.540001   29.117500   29.195000
# 2017-01-09   28.083660   29.747499   29.857500   29.485001   29.487499
# ...                ...         ...         ...         ...         ...
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1113 non-null   float64
#  1   (Adj Close, IBM)   1113 non-null   float64
#  2   (Adj Close, INTC)  1113 non-null   float64
#  3   (Adj Close, MSFT)  1113 non-null   float64
#  4   (Adj Close, NVDA)  1113 non-null   float64
#  5   (Adj Close, QYLD)  1113 non-null   float64
#  6   (Close, AAPL)      1113 non-null   float64
#  7   (Close, IBM)       1113 non-null   float64
#  8   (Close, INTC)      1113 non-null   float64
#  9   (Close, MSFT)      1113 non-null   float64
#  10  (Close, NVDA)      1113 non-null   float64
#  11  (Close, QYLD)      1113 non-null   float64
#  12  (High, AAPL)       1113 non-null   float64
#  13  (High, IBM)        1113 non-null   float64
#  14  (High, INTC)       1113 non-null   float64
#  15  (High, MSFT)       1113 non-null   float64
#  16  (High, NVDA)       1113 non-null   float64
#  17  (High, QYLD)       1113 non-null   float64
#  18  (Low, AAPL)        1113 non-null   float64
#  19  (Low, IBM)         1113 non-null   float64
#  20  (Low, INTC)        1113 non-null   float64
#  21  (Low, MSFT)        1113 non-null   float64
#  22  (Low, NVDA)        1113 non-null   float64
#  23  (Low, QYLD)        1113 non-null   float64
#  24  (Open, AAPL)       1113 non-null   float64
#  25  (Open, IBM)        1113 non-null   float64
#  26  (Open, INTC)       1113 non-null   float64
#  27  (Open, MSFT)       1113 non-null   float64
#  28  (Open, NVDA)       1113 non-null   float64
#  29  (Open, QYLD)       1113 non-null   float64
#  30  (Volume, AAPL)     1113 non-null   int64
#  31  (Volume, IBM)      1113 non-null   int64
#  32  (Volume, INTC)     1113 non-null   int64
#  33  (Volume, MSFT)     1113 non-null   int64
#  34  (Volume, NVDA)     1113 non-null   int64
#  35  (Volume, QYLD)     1113 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 321.7 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL          IBM         INTC         MSFT         NVDA
# count  1113.000000  1113.000000  1113.000000  1113.000000  1113.000000
# mean     63.737921   125.009528    46.901030   132.440941   268.447324
# std      32.237237    10.098274     8.984929    57.575885   147.320802
# min      27.382690    88.795891    30.286913    58.142242    94.416542
# 25%      40.657410   119.774628    42.116215    87.048904   163.415955
# 50%      49.715195   124.907394    47.105358   114.554131   219.603546
# 75%      78.652542   130.139420    53.022831   180.066498   294.288940
# max     142.704010   149.450806    67.842155   261.366486   703.130005
#
#                           Close                                         ...  \
#               QYLD         AAPL          IBM         INTC         MSFT  ...
# count  1113.000000  1113.000000  1113.000000  1113.000000  1113.000000  ...
# mean     18.105592    64.856673   139.864187    49.366262   135.291105  ...
# std       2.035583    31.776701    15.945133     8.302547    56.495909  ...
# min      14.211367    29.004999    94.769997    33.459999    62.299999  ...
# 25%      16.615658    42.275002   126.139999    44.939999    90.809998  ...
# 50%      17.892370    50.715000   140.559998    49.389999   117.519997  ...
# 75%      19.372456    79.425003   149.839996    55.490002   181.809998  ...
# max      22.547661   143.160004   181.949997    68.470001   261.970001  ...
#
#               Open                                               Volume  \
#               INTC         MSFT         NVDA         QYLD          AAPL
# count  1113.000000  1113.000000  1113.000000  1113.000000  1.113000e+03
# mean     49.344492   135.252983   269.419704    23.055398  1.258960e+08
# std       8.299332    56.453564   146.937258     1.352827  5.707977e+07
# min      33.250000    62.189999    96.010002    17.799999  4.544800e+07
# 25%      45.150002    90.559998   165.000000    22.379999  8.738880e+07
# 50%      49.349998   117.389999   222.220001    23.129999  1.099312e+08
# 75%      55.279999   182.539993   296.769989    23.990000  1.463228e+08
# max      68.199997   261.660004   684.500000    25.500000  4.479400e+08
#
#
#                 IBM          INTC          MSFT          NVDA          QYLD
# count  1.113000e+03  1.113000e+03  1.113000e+03  1.113000e+03  1.113000e+03
# mean   4.881915e+06  2.728322e+07  2.902405e+07  1.309322e+07  3.929829e+05
# std    3.032037e+06  1.382849e+07  1.315556e+07  7.316223e+06  5.206336e+05
# min    1.193000e+06  6.313200e+06  7.425600e+06  2.447100e+06  5.200000e+03
# 25%    3.241100e+06  1.891800e+07  2.066400e+07  8.380200e+06  6.850000e+04
# 50%    4.083900e+06  2.379560e+07  2.551070e+07  1.130190e+07  2.029000e+05
# 75%    5.398900e+06  3.130500e+07  3.319440e+07  1.592610e+07  5.012000e+05
# max    3.806350e+07  1.822699e+08  1.112421e+08  9.232320e+07  4.426500e+06
#
# [8 rows x 36 columns]

# %%
close = stocks.loc[:, "Adj Close"].copy()

# %%
close.head()
# Out:
#                  AAPL         IBM       INTC       MSFT        NVDA       QYLD
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099  14.211367
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380  14.300344
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482  14.338478
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492  14.402037
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300  14.452879

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                  AAPL         IBM       INTC       MSFT        NVDA       QYLD
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099  14.211367
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380  14.300344
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482  14.338478
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492  14.402037
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300  14.452879

# %%
close.iloc[0,0]
# Out:
# 27.41337203979492

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2017-01-03    100.000000
# 2017-01-04     99.888078
# 2017-01-05    100.396055
# 2017-01-06    101.515289
# 2017-01-09    102.445114
#                  ...
# 2021-05-28    454.559185
# 2021-06-01    453.355387
# 2021-06-02    456.200709
# 2021-06-03    450.655982
# 2021-06-04    459.228435
# Name: AAPL, Length: 1113, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     27.413372
# IBM     136.249847
# INTC     32.651402
# MSFT     58.403568
# NVDA    100.736099
# QYLD     14.211367
# Name: 2017-01-03 00:00:00, dtype: float64

# %%
norm = close.div(close.min()).sub(1)
norm
# Out:
#                 AAPL       IBM      INTC      MSFT      NVDA      QYLD
# Date
# 2017-01-03  0.001120  0.534416  0.078070  0.004495  0.066933  0.000000
# 2017-01-04  0.000000  0.553414  0.072473  0.000000  0.091825  0.006261
# 2017-01-05  0.005085  0.548274  0.070706  0.000000  0.064109  0.008944
# 2017-01-06  0.016290  0.555892  0.074535  0.008668  0.078333  0.013417
# 2017-01-09  0.025599  0.538638  0.078365  0.005458  0.122052  0.016994
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-28  3.550685  0.618769  0.885963  3.294296  5.882057  0.562833
# 2021-06-01  3.538634  0.623836  0.878369  3.255082  5.890530  0.564241
# 2021-06-02  3.567119  0.641067  0.897849  3.253362  6.108182  0.565648
# 2021-06-03  3.511609  0.639152  0.856908  3.226015  6.189312  0.559315
# 2021-06-04  3.597430  0.660212  0.894217  3.313387  6.447106  0.571277
#
# [1113 rows x 6 columns]

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## The shift() method

# %%
close.head()
# Out:
#                  AAPL         IBM       INTC       MSFT        NVDA       QYLD
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099  14.211367
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380  14.300344
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482  14.338478
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492  14.402037
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300  14.452879

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                  AAPL
# Date
# 
financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                  AAPL         IBM       INTC       MSFT        NVDA       QYLD
# Date
# 2017-01-03  27.413372  136.249847  32.651402  58.403568  100.736099  14.211367
# 2017-01-04  27.382690  137.936768  32.481903  58.142242  103.086380  14.300344
# 2017-01-05  27.521944  137.480408  32.428375  58.142242  100.469482  14.338478
# 2017-01-06  27.828764  138.156799  32.544357  58.646210  101.812492  14.402037
# 2017-01-09  28.083660  136.624695  32.660336  58.459557  105.940300  14.452879

# %%
close.pct_change().dropna()
# Out:
#                 AAPL       IBM      INTC      MSFT      NVDA      QYLD
# Date
# 2017-01-04 -0.001119  0.012381 -0.005191 -0.004474  0.023331  0.006261
# 2017-01-05  0.005085 -0.003308 -0.001648  0.000000 -0.025385  0.002667
# 2017-01-06  0.011148  0.004920  0.003577  0.008668  0.013367  0.004433
# 2017-01-09  0.009159 -0.011090  0.003564 -0.003183  0.040543  0.003530
# 2017-01-10  0.001008 -0.012705 -0.001912 -0.000319 -0.007550 -0.000616
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-28 -0.005348 -0.000556 -0.010566  0.001484  0.048844  0.001353
# 2021-06-01 -0.002648  0.003131 -0.004027 -0.009132  0.001231  0.000901
# 2021-06-02  0.006276  0.010611  0.010371 -0.000404  0.031587  0.000900
# 2021-06-03 -0.012154 -0.001167 -0.021573 -0.006429  0.011414 -0.004045
# 2021-06-04  0.019022  0.012848  0.020092  0.020675  0.035858  0.007671
#
# [1112 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL       IBM      INTC      MSFT      NVDA      QYLD
# Date
# 2017-01-04 -0.001119  0.012381 -0.005191 -0.004474  0.023331  0.006261
# 2017-01-05  0.005085 -0.003308 -0.001648  0.000000 -0.025385  0.002667
# 2017-01-06  0.011148  0.004920  0.003577  0.008668  0.013367  0.004433
# 2017-01-09  0.009159 -0.011090  0.003564 -0.003183  0.040543  0.003530
# 2017-01-10  0.001008 -0.012705 -0.001912 -0.000319 -0.007550 -0.000616

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#           mean       std
# AAPL  0.001568  0.019803
# IBM   0.000217  0.017027
# INTC  0.000762  0.022512
# MSFT  0.001472  0.017900
# NVDA  0.002197  0.029814
# QYLD  0.000464  0.010709

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001568  0.019803
# IBM   0.000217  0.017027
# INTC  0.000762  0.022512
# MSFT  0.001472  0.017900
# NVDA  0.002197  0.029814
# QYLD  0.000464  0.010709

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.395123  0.314363
# IBM   0.054577  0.270292
# INTC  0.192002  0.357373
# MSFT  0.370825  0.284159
# NVDA  0.553586  0.473289
# QYLD  0.117016  0.170006

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ## Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL       IBM      INTC      MSFT      NVDA      QYLD
# Date
# 2017-01-04 -0.001119  0.012381 -0.005191 -0.004474  0.023331  0.006261
# 2017-01-05  0.005085 -0.003308 -0.001648  0.000000 -0.025385  0.002667
# 2017-01-06  0.011148  0.004920  0.003577  0.008668  0.013367  0.004433
# 2017-01-09  0.009159 -0.011090  0.003564 -0.003183  0.040543  0.003530
# 2017-01-10  0.001008 -0.012705 -0.001912 -0.000319 -0.007550 -0.000616

# %%
ret.cov()
# Out:
#           AAPL       IBM      INTC      MSFT      NVDA      QYLD
# AAPL  0.000392  0.000152  0.000252  0.000264  0.000365  0.000159
# IBM   0.000152  0.000290  0.000198  0.000162  0.000200  0.000100
# INTC  0.000252  0.000198  0.000507  0.000258  0.000373  0.000157
# MSFT  0.000264  0.000162  0.000258  0.000320  0.000355  0.000158
# NVDA  0.000365  0.000200  0.000373  0.000355  0.000889  0.000216
# QYLD  0.000159  0.000100  0.000157  0.000158  0.000216  0.000115

# %%
ret.corr()
# Out:
#           AAPL       IBM      INTC      MSFT      NVDA      QYLD
# AAPL  1.000000  0.452190  0.564267  0.744134  0.617465  0.751617
# IBM   0.452190  1.000000  0.517112  0.530810  0.394117  0.548729
# INTC  0.564267  0.517112  1.000000  0.639620  0.555562  0.652950
# MSFT  0.744134  0.530810  0.639620  1.000000  0.665031  0.824404
# NVDA  0.617465  0.394117  0.555562  0.665031  1.000000  0.675726
# QYLD  0.751617  0.548729  0.652950  0.824404  0.675726  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()

# %% [markdown]
# ## Simple Returns vs. Log Returns

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(index = [2016, 2017, 2018], data = [100, 50, 95], columns = ["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_returns = df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100 * 1.2 * 1.2
# Out:
# 144.0

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
np.log(df / df.shift(1))
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
np.log(100)
# Out:
# 4.605170185988092

# %%
log_returns = np.log(df / df.shift(1)).dropna()

# %%
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100 * np.exp(2 * log_returns.mean())
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ## Importing Financial Data from Excel

# %%
import pandas as pd
import xlrd

# %%
pd.read_excel("SP500.xls").head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 1970-12-31  92.269997  92.790001  91.360001  92.150002  92.150002  13390000
# 1 1971-01-04  92.150002  92.190002  90.639999  91.150002  91.150002  10010000
# 2 1971-01-05  91.150002  92.279999  90.690002  91.800003  91.800003  12600000
# 3 1971-01-06  91.800003  93.000000  91.500000  92.349998  92.349998  16960000
# 4 1971-01-07  92.349998  93.260002  91.750000  92.379997  92.379997  16460000

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date")
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1970-12-31    92.269997    92.790001    91.360001    92.150002    92.150002
# 1971-01-04    92.150002    92.190002    90.639999    91.150002    91.150002
# 1971-01-05    91.150002    92.279999    90.690002    91.800003    91.800003
# 1971-01-06    91.800003    93.000000    91.500000    92.349998    92.349998
# 1971-01-07    92.349998    93.260002    91.750000    92.379997    92.379997
# ...                 ...          ...          ...          ...          ...
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990  2485.739990
#
#                 Volume
# Date
# 1970-12-31    13390000
# 1971-01-04    10010000
# 1971-01-05    12600000
# 1971-01-06    16960000
# 1971-01-07    16460000
# ...                ...
# 2018-12-21  -980924592
# 2018-12-24 -1681037296
# 2018-12-26   -60977296
# 2018-12-27  -198357296
# 2018-12-28  -592347296
#
# [12107 rows x 6 columns]

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols = "A, C:E,G")
# Out:
#                    High          Low        Close      Volume
# Date
# 1970-12-31    92.790001    91.360001    92.150002    13390000
# 1971-01-04    92.190002    90.639999    91.150002    10010000
# 1971-01-05    92.279999    90.690002    91.800003    12600000
# 1971-01-06    93.000000    91.500000    92.349998    16960000
# 1971-01-07    93.260002    91.750000    92.379997    16460000
# ...                 ...          ...          ...         ...
# 2018-12-21  2504.409912  2408.550049  2416.620117  -980924592
# 2018-12-24  2410.340088  2351.100098  2351.100098 -1681037296
# 2018-12-26  2467.760010  2346.580078  2467.699951   -60977296
# 2018-12-27  2489.100098  2397.939941  2488.830078  -198357296
# 2018-12-28  2520.270020  2472.889893  2485.739990  -592347296
#
# [12107 rows x 4 columns]

# %%
pd.read_excel("SP500.xls", sheet_name= "Sales")
# Out:
#   Unnamed: 0      City  Sales
# 0       Mike  New York     25
# 1        Jim    Boston     43
# 2     Steven    London     76
# 3        Joe    Madrid     12
# 4        Tom     Paris     89

# %%
SP500 = pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols= "A:E")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.describe()
# Out:
#                Open          High           Low         Close
# count  12107.000000  12107.000000  12107.000000  12107.000000
# mean     789.789521    794.483210    784.788567    789.943885
# std      702.572916    705.945551    698.834491    702.590071
# min       62.279999     63.230000     60.959999     62.279999
# 25%      141.444999    142.330001    140.245002    141.644996
# 50%      471.049988    473.130005    469.500000    471.059998
# 75%     1267.385010   1275.375000   1259.465027   1267.405029
# max     2936.760010   2940.909912   2927.110107   2930.750000

# %%
SP500.to_csv("SP500.csv")

# %%
import xlwt
SP500.to_excel("SP500_red.xls")
# Out:
# <ipython-input-105-e61e31041f2c>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   SP500.to_excel("SP500_red.xls")

# %% [markdown]
# ## Simple Moving Averages (SMA) with rolling()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates = ["Date"], index_col = "Date")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12107 entries, 1970-12-31 to 2018-12-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    12107 non-null  float64
#  1   High    12107 non-null  float64
#  2   Low     12107 non-null  float64
#  3   Close   12107 non-null  float64
# dtypes: float64(4)
# memory usage: 472.9 KB

# %%
SP500 = SP500.Close.to_frame()

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500.plot(figsize = (12,8), fontsize= 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.rolling(window = 10)
# Out:
# Rolling [window=10,center=False,axis=0]

# %%
type(SP500.rolling(window = 10))
# Out:
# pandas.core.window.rolling.Rolling

# %%
SP500.head(15)
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024
# 2009-01-08  909.729980
# 2009-01-09  890.349976
# 2009-01-12  870.260010
# 2009-01-13  871.789978
# 2009-01-14  842.619995
# 2009-01-15  843.739990
# 2009-01-16  850.119995
# 2009-01-20  805.219971
# 2009-01-21  840.239990
# 2009-01-22  827.500000

# %%
SP500.rolling(window = 10).median()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2573.054931
# 2018-12-24  2546.049926
# 2018-12-26  2526.449951
# 2018-12-27  2497.895019
# 2018-12-28  2487.285034
#
# [2516 rows x 1 columns]

# %%
SP500.rolling(window = 10, min_periods=5).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07   920.770007
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %% [markdown]
# ## Momentum Trading Strategies with SMAs

# %%
SP500.head()
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024

# %%
SP500.tail()
# Out:
#                   Close
# Date
# 2018-12-21  2416.620117
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990

# %%
SP500["SMA50"] = SP500.rolling(window = 50, min_periods=50).mean()

# %%
SP500
# Out:
#                   Close        SMA50
# Date
# 2008-12-31   903.250000          NaN
# 2009-01-02   931.799988          NaN
# 2009-01-05   927.450012          NaN
# 2009-01-06   934.700012          NaN
# 2009-01-07   906.650024          NaN
# ...                 ...          ...
# 2018-12-21  2416.620117  2692.420195
# 2018-12-24  2351.100098  2684.874795
# 2018-12-26  2467.699951  2678.886196
# 2018-12-27  2488.830078  2673.646997
# 2018-12-28  2485.739990  2667.163398
#
# [2516 rows x 2 columns]

# %%
SP500.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500["SMA200"] = SP500.Close.rolling(window = 200).mean()

# %%
SP500.tail()
# Out:
#                   Close        SMA50      SMA200
# Date
# 2018-12-21  2416.620117  2692.420195  2753.65980
# 2018-12-24  2351.100098  2684.874795  2751.48245
# 2018-12-26  2467.699951  2678.886196  2749.90585
# 2018-12-27  2488.830078  2673.646997  2748.52345
# 2018-12-28  2485.739990  2667.163398  2747.20475

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2008-12-31 to 2018-12-28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2516 non-null   float64
#  1   SMA50   2467 non-null   float64
#  2   SMA200  2317 non-null   float64
# dtypes: float64(3)
# memory usage: 78.6 KB

# %%
SP500.plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ## Exponentially-weighted Moving Averages (EWMA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates= ["Date"], index_col= "Date", usecols= ["Date", "Close"])

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.Close.rolling(window = 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2565.915991
# 2018-12-24    2537.254004
# 2018-12-26    2520.345996
# 2018-12-27    2504.121997
# 2018-12-28    2487.641992
# Name: Close, Length: 2516, dtype: float64

# %%
SP500.Close.ewm(span = 10, min_periods= 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2547.124619
# 2018-12-24    2511.483797
# 2018-12-26    2503.523098
# 2018-12-27    2500.851640
# 2018-12-28    2498.104067
# Name: Close, Length: 2516, dtype: float64

# %%
SP500["SMA"] = SP500.Close.rolling(window = 100).mean()
SP500["EMA"] = SP500.Close.ewm(span = 100, min_periods= 100).mean()

# %%
SP500
# Out:
#                   Close          SMA          EMA
# Date
# 2008-12-31   903.250000          NaN          NaN
# 2009-01-02   931.799988          NaN          NaN
# 2009-01-05   927.450012          NaN          NaN
# 2009-01-06   934.700012          NaN          NaN
# 2009-01-07   906.650024          NaN          NaN
# ...                 ...          ...          ...
# 2018-12-21  2416.620117  2785.905496  2732.088580
# 2018-12-24  2351.100098  2781.282896  2724.544253
# 2018-12-26  2467.699951  2777.687695  2719.458228
# 2018-12-27  2488.830078  2774.172495  2714.891334
# 2018-12-28  2485.739990  2770.525896  2710.353683
#
# [2516 rows x 3 columns]

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize =15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ### Merging Time Series

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0]).Close

# %%
stocks.head()
# Out:
#                  AAPL         IBM       INTC       MSFT        NVDA       QYLD
# Date
# 2017-01-03  29.037500  167.190002  36.599998  62.580002  102.010002  22.360001
# 2017-01-04  29.004999  169.259995  36.410000  62.299999  104.389999  22.500000
# 2017-01-05  29.152500  168.699997  36.349998  62.299999  101.739998  22.559999
# 2017-01-06  29.477501  169.529999  36.480000  62.840000  103.099998  22.660000
# 2017-01-09  29.747499  167.649994  36.610001  62.639999  107.279999  22.740000

# %%
aapl = stocks.loc["2010-01-01" : "2014-12-31", "AAPL"].to_frame()
aapl.head()
# Out:
# Empty DataFrame
# Columns: [AAPL]
# Index: []

# %%
ba = stocks.loc["2012-01-01" : "2016-12-31", "BA"].to_frame()
ba.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-d30684ed4e3c> in <module>
# ----> 1 ba = stocks.loc["2012-01-01" : "2016-12-31", "BA"].to_frame()
#       2 ba.head()
#       3
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3722         if axis == 1:
#    3723             if drop_level:
# -> 3724                 return self[key]
#    3725             index = self.columns
#    3726         else:
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\joisl\pycharmprojects\oanda\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'BA'

# %%
aapl["BA"] = ba.BA

# %%
aapl.head()

# %%
aapl.tail()

# %%
aapl.dropna()

# %%
ba.reindex(aapl.index).dropna()

# %%
dis = stocks.loc["2010-01-01" : "2016-12-31", "DIS"].resample("W-Fri").last().to_frame()
dis.head()

# %%
aapl.head()

# %%
aapl["DIS"] = dis.DIS

# %%
aapl.head(10)

# %%
dis.reindex(aapl.index)

# %%
dis["AAPL"] = aapl.AAPL

# %%
dis.head(10)
